# %% [markdown]
# ## Initialization, data loading

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '../src/')
from analyzer import ExperimentAnalyzer, plot_typography
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_typography(usetex=False)
SAVE = False

# %%
START_IDX = 0
STOP_IDX = None
STEADY_STATE_START_IDX = 500
STEADY_STATE_STOP_IDX = None
FIGSIZE = (8,5)

# %%
analyzer = ExperimentAnalyzer("detumbling_eci", decimate_step=4, log_dir="log") # use decimate step of four to get seconds as the sampling time is 250ms

# %% [markdown]
# # Angular velocity

# %% [markdown]
# ### Compare groud truth and prediction

# %%
analyzer.plot_detumbling_mc(START_IDX, STOP_IDX, figsize=(8,5), save=SAVE)
# Out:
# omega
# Mean=52.300s, std=31.974s, min=28.000s, max=160.000s
