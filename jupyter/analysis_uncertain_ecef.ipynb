# %% [markdown]
# ## Initialization, data loading

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '../src/')
from analyzer import ExperimentAnalyzer, plot_typography

# %%
plot_typography(usetex=True)
SAVE = False
FIGSIZE=(8,5)

# %%
START_IDX = 0
STOP_IDX = None
STEADY_STATE_START_IDX = 100
STEADY_STATE_STOP_IDX = 100

# %%
MULTIPLOT_COLOR = "tab:blue"

# %%
analyzer = ExperimentAnalyzer("uncertain_ecef", decimate_step=4, log_dir="log") # use decimate step of four to get seconds as the sampling time is 250ms

# %% [markdown]
# # Angular velocity

# %% [markdown]
# ### Compare groud truth and prediction

# %%
analyzer.plot_omega_error(START_IDX, STOP_IDX, figsize=FIGSIZE, save=SAVE)
# Out:
# omega
# Mean omega error=95.3345746636446 (std=293.7066449395117) in arcsec/s

# %%
analyzer.plot_detumbling_mc(START_IDX, 345, figsize=FIGSIZE,  save=SAVE)
# Out:
# omega
# Mean=26.567s, std=3.253s, min=20.000s, max=32.000s

# %% [markdown]
# # Orientation

# %%
analyzer.plot_ads_error(START_IDX+30, None, figsize=FIGSIZE, save=SAVE)
# Out:
# ads_error_angles
# ads_ref_error_angles
# Mean errors: proposed=0.3049455899313711 (std=0.4634168640716577), reference=1.1388430288676827 (std=0.5480225193965351) in arcseconds

# %%
analyzer.plot_ads_error_mc(START_IDX, STOP_IDX, plot_legend=False, multiplot_color=MULTIPLOT_COLOR, figsize=FIGSIZE, save=SAVE)
# Out:
# ads_error_angles
# Mean ADS angle error=62.28440833633448, std=173.98707532076824 in arcseconds

# %% [markdown]
# # Actuator signals

# %%
_ = analyzer.plot_separate(["h_rw", "rw_torques", "mtq_m", "hybrid_torques", "mtq_torques"],
                                 START_IDX, STOP_IDX, figsize=FIGSIZE, save=SAVE)
# Out:
# h_rw
# rw_torques
# mtq_m
# hybrid_torques
# mtq_torques
